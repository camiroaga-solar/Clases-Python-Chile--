# %% [markdown]
# # Clase 1: Introducción a Python y Google Colab

# %% [markdown]
# #1) Escribir texto en el cuaderno

# %% [markdown]
# Esto es un cuaderno de  Python en Google Colab. Acá vas a encontrar explicaciones de los conceptos juntos con todos los programas de Python que vamos a usar en este curso.
#
# Antes de comenzar, una pregunta que definirá tu futuro en la programación:

# %% [markdown]
# **¿Cúal de estos tres prefieres?**
#
# a) Gato 🐈
#
# b) Cangrejo 🦀
#
# c) Corgi 🐶
#
# Anda a "Configuración" (arriba a la derecha), luego a "Varios" y elige tu favorito 😜.

# %% [markdown]
# Como puedes ver, Google Colab puede ser usado para hacer cuadernos con diferentes tipos de texto o imágenes.
#
# Tú también puedes editar el texto haciendo doble click. Por ejemplo, edita el siguiente bloque de texto para poner tu nombre.

# %% [markdown]
# **Nombre del tutor: Javier Contreras**
#
# **Nombre del estudiante: Daniel Campos**
#
# **Animal elegido (gato, cangrejo, corgi): Gatito**

# %% [markdown]
# También puedes agregar tus propios bloques de texto. Existen dos maneras de hacerlo:
#
# 1) Ir a **"Insertar"**, y luego **"Celda de texto"**
#
# 2) Mover el mouse al border superior o inferior de un bloque, y hacer click en "+ Texto"
#
#
#
# **¡Inserta un bloque de texto acá abajo y escribe algo!**

# %% [markdown]
# # 2) Escribir y ejecutar programas de Python

# %% [markdown]
# ## Ejecutar un "Hola, Mundo"

# %% [markdown]
# En Google Colab, puedes escribir código Python en **celdas de código**. Para crear una nueva celda de código, haz clic en **"+ Código"** en la barra de herramientas o usa el atajo de teclado **"Ctrl + M B"**.
#
# Las celdas de código contienen **programas de Python.** No están diseñadas para contener texto, sino para tener programas de Python que **serán ejecutados**.
#
# Para ejecutar una celda de código, haz clic en el botón de reproducción a la izquierda de la celda o presiona "Shift + Enter".
#
# Aquí tienes un ejemplo simple:

# %%
print("¡Hola, mundo!")
# Out:
# ¡Hola, mundo!

# %% [markdown]
# "Ejecutar un programa" significa básicamente decirle al computador **"haz estas instrucciones"**.
#
# En este caso, **"print"** significa **"Imprime"** o **"muestra"** el texto entre paréntesis.

# %%
print("Galleta")
# Out:
# Galleta

# %% [markdown]
# Python es muy inteligente y puede hacer cálculos e imprimirlos muy rápido. Veamos uno:

# %%
print(4+10)
# Out:
# 4+10

# %% [markdown]
# Otros:

# %%
print(81/9)
# Out:
# 9.0

# %%
print(3434343*3434343)
# Out:
# 11794711841649

# %% [markdown]
# ¡Qué rápido!

# %% [markdown]
# ## Ejercicio 1

# %% [markdown]
# Escribe un comando para escribir tu nombre usando "print()". Utiliza el bloque de código de acá abajo:

# %%
# Out:
# David

# %% [markdown]
# ¡Felicidades! 🥳🥳🥳🥳🥳🥳
#
# Has escrito tu primer programa de Python. ¡Será el primero de muchos!

# %% [markdown]
# ## Ejercicio 2

# %% [markdown]
# Escribe un "print" para saber el número de minutos en un año. Recuerda que
#
# 1)En un año hay 365 días (ignoremos los años bisiestos)
#
# 2)En un día hay 24 horas
#
# 3)En una hora hay 60 minutos

# %%
print(365*24*60)
# Out:
# 525600

# %% [markdown]
# ## Errores en Python

# %% [markdown]
# Como decía en la presentación, para que un computador entienda tus instrucciones, tienes que seguir reglas muy específicas.
#
# Si no sigues estas reglas, el computador no entenderá lo que quieres decir y explotará en mil pedazos (metafóricamente). Cuando el computador no entiende lo que quieres decir, te tira un "error".
#
# Veamos qué pasa si omitimos un paréntesis en el "print"

# %%
print("Minion
# Out:
#   File "<ipython-input-11-00bfc1a1a2b1>", line 1
#     print("Minion
#           ^
# SyntaxError: unterminated string literal (detected at line 1)

# %% [markdown]
# ¡Tu primer error!
#
# Pero no te preocupes, recibir un error significa que te estás acercando a la verdad. Un error ocurre cuando rompes alguna regla del lenguaje de programación, o el computador no entiende qué quieres decirle.
#
# ¿Qué pasa si escribimos "02" en vez de "2"?

# %%
print(2)
# Out:
#   File "<ipython-input-15-87a844b0eb76>", line 1
#     print(02)
#           ^
# SyntaxError: leading zeros in decimal integer literals are not permitted; use an 0o prefix for octal integers

# %% [markdown]
# ¡Otro error, solo por escribir "02" en vez de "2"!
#
# Python es muy estricto con cómo se tienen que escribir las instrucciones en su lenguaje. Si te desvías tan solo un poco de las reglas, no se podrá ejecutar un programa.
#
# ¿Qué crees que pasará si escribimos un print de un texto sin usar las comillas?

# %%
print(Galleta)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-14-d46aedf95ef8> in <cell line: 1>()
# ----> 1 print(Galleta)
#
# NameError: name 'Galleta' is not defined

# %% [markdown]
# ## Más comandos con "print"

# %% [markdown]
# ¿Qué crees que pasará si ejecutamos esto?

# %%
print("Hola" + "Galleta")
# Out:
# HolaGalleta

# %% [markdown]
# Intentemos arreglarlo para que haya un espacio entre el texto

# %%
print("Hola " + "Galleta")
# Out:
# Hola Galleta

# %% [markdown]
# Otra manera de hacerlo es usando una coma en vez del signo más

# %%
print("hola", "minion")
# Out:
# hola minion

# %% [markdown]
# ¿Qué crees que hará esto?

# %%
print("bla"*3)
# Out:
# blablabla

# %% [markdown]
# ##Ejercicio 3

# %% [markdown]
# Escribe un comando "print" que imprima el texto "hola oruga" 20 veces. Tiene que haber un espacio entre todos los "hola oruga"

# %%
print(("hola oruga "*20)
# Out:
# hola orugaorugaorugaorugaorugaorugaorugaorugaorugaorugaorugaorugaorugaorugaorugaorugaorugaorugaorugaoruga

# %% [markdown]
# ## Ejecutar otros programas de prueba en Python

# %% [markdown]
# Aquí mismo en Google Colab, podemos ejecutar toda clase de comandos y programas, no solo resultados matemáticos. Examinemos algunos ejemplos para ver qué tipo de cosas se pueden hacer en Python.
#
# No te preocupes en entender el código, pero veamos qué pasa cuando apretamos el botón de "Ejecutar".

# %%
import random

print("¡Bienvenido al juego de adivinanzas!")
print("Estoy pensando en un número entre 1 y 100.")

numero_secreto = random.randint(1, 100)
intentos = 0

while True:
    intentos += 1
    suposicion = int(input("Ingresa tu suposición: "))

    if suposicion < numero_secreto:
        print("Demasiado bajo. Intenta de nuevo.")
    elif suposicion > numero_secreto:
        print("Demasiado alto. Intenta de nuevo.")
    else:
        print("¡Felicitaciones! ¡Adivinaste el número en", intentos, "intentos!")
        break

print("Gracias por jugar.")
# Out:
# ¡Bienvenido al juego de adivinanzas!
# Estoy pensando en un número entre 1 y 100.
# Ingresa tu suposición: 12
# Demasiado bajo. Intenta de nuevo.
# Ingresa tu suposición: 50
# Demasiado bajo. Intenta de nuevo.
# Ingresa tu suposición: 90
# ¡Felicitaciones! ¡Adivinaste el número en 3 intentos!
# Gracias por jugar.

# %% [markdown]
# Entretenido, ¿no?
#
# ¡Dentro de algunas sesiones tú mismo/a vas a poder hacer este juego!
#
# Veamos este otro. Intenta hacer click en los botones

# %%
from ipywidgets import Button, Layout, VBox, Output
from IPython.display import display

def on_button_clicked(b):
    with output:
        output.clear_output()
        if b.description == '¡Hola!':
            print("¡Hola, minion!")
        elif b.description == 'Adiós':
            print("Chao minion.")


button_hello = Button(description='¡Hola!', button_style='success', layout=Layout(height='auto', width='auto'))
button_bye = Button(description='Adiós', button_style='danger', layout=Layout(height='auto', width='auto'))
output = Output()
button_hello.on_click(on_button_clicked)
button_bye.on_click(on_button_clicked)

display(VBox([button_hello, button_bye, output]))

# %% [markdown]
# Otro más. Lee este código antes de ejecutarlo, ¿qué crees que hará?

# %%
import folium

latitud_chile = -35.675147
longitud_chile = -71.542969
mapa_chile = folium.Map(location=[latitud_chile, longitud_chile], zoom_start=4)

folium.Marker(
    [-33.448890, -70.669265],
    popup='Santiago',
    tooltip='Santiago de Chile'
).add_to(mapa_chile)

folium.Marker(
    [-33.047238, -71.612688],
    popup='Valparaíso',
    tooltip='Valparaíso'
).add_to(mapa_chile)

folium.Marker(
    [-24.5, -69.25],
    popup='Desierto de Atacama',
    tooltip='Desierto de Atacama'
).add_to(mapa_chile)
mapa_chile
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
# ...

# %% [markdown]
# ¡Un mapa!
#
# Veamos este otro. De nuevo, no te preocupes por el código, pero experimenta con los sliders que dicen "R,G,y B". ¿Qué significan?

# %%
# Importar las bibliotecas necesarias
import matplotlib.pyplot as plt
from matplotlib.patches import Rectangle
from ipywidgets import interactive

# Función para mostrar un rectángulo con un color basado en valores RGB
def dibujar_rectangulo_colorido(R=255, G=255, B=255):
    # Crear una nueva figura y ejes
    fig, ax = plt.subplots(figsize=(6, 3))

    # Añadir un rectángulo a los ejes
    rect = Rectangle((0.1, 0.1), 0.8, 0.8, color=(R/255, G/255, B/255))
    ax.add_patch(rect)

    # Establecer límites y apagar los ejes para una mejor visualización
    ax.set_xlim(0, 1)
    ax.set_ylim(0, 1)
    ax.axis('off')

    plt.show()

# Crear controles deslizantes interactivos para cada componente RGB
plot_interactivo = interactive(dibujar_rectangulo_colorido, R=(0, 255), G=(0, 255), B=(0, 255))
salida = plot_interactivo.children[-1]
salida.layout.height = '250px' # Ajustar la altura de la trama de salida

# Mostrar el widget interactivo
plot_interactivo
# Out:
# interactive(children=(IntSlider(value=255, description='R', max=255), IntSlider(value=255, description='G', ma…

# %% [markdown]
# ¡Interesante! **R, G y B** significan "Red", "Green" y "Blue", y nos permiten generar todos los colores a través de la combinación de estos tres.
#
# Intenta ahora crear un rectángulo rojo, uno azul y uno verde.
#
# Una más difícil: ¿puedes crear uno morado?
#
# Todavía más difícil: ¿uno negro? ¿y uno blanco?
#
# Veamos otro ejemplo de un programa interactivo de Python. Quizás se demora un poco en ejectuar, pero vale completamente la pena esperar por él.

# %%
# !pip3 install ColabTurtlePlus

from ColabTurtlePlus.Turtle import *

clearscreen()
setup(400, 400)
showborder()
color("black","green")
shape("turtle")
pensize(2)
speed(7)

def petal():
    begin_fill()
    circle(50, 90)
    left(90)
    circle(50, 90)
    end_fill()

for _ in range(12):
    petal()
    left(60)

saveSVG(turtle=True)
# Out:
# ...
# Put clearscreen() as the first line in a cell (after the import command) to re-run turtle commands in the cell
#       <svg width="400" height="400">
#         <rect width="100%" height="100%" style="fill:white;stroke:gray;stroke-width:1"/>
#
#
# ...

# %% [markdown]
# ¡Es una tortuga 🐢 que nos permite hacer dibujos!
#
# En este curso aprenderás a hacer este dibujo y otros más con esta tortuga 🐢

# %% [markdown]
# Como puedes ver, en Google Colab se pueden ejecutar programas de Python de todo tipo, incluyendo programas interactivos, sin necesidad de instalar nada en nuestros computadores. ¡Es todo en línea!

# %% [markdown]
# # 3) Comentarios en Python

# %% [markdown]
# Como explicamos más arriba:
#
# **Las celdas de texto** contienen texto, por ejemplo explicaciones.
#
# **Las celdas de código** contienen programas que podemos ejecutar, apretando el botón "Play".
#
# Pero, ¿qué pasa si queremos poner una explicación dentro de una celda de código? Podemos hacer esto:

# %%
#Imprime un texto
print("galleta")
# Out:
# galleta

# %% [markdown]
# El texto después del hashtag o gato 🐱 se llama "Comentario". Los comentarios son textos que nos permiten entender mejor el programa, pero **no son procesados por el computador cuando son ejecutados**.
#
# Es decir, **no afectan el resultado final del programa**. Pero sí hacen más fácil que nosotros u otras personas comprendan mejor qué ocurre dentro del programa.

# %%
#Calcula el número de huevos en 8 docenas de huevos

print("El número de huevos es:")
print(8*12)
# Out:
# 96

# %% [markdown]
# ##Ejercicio 4

# %% [markdown]
# Experimenta, responde estas preguntas y luego **añade comentarios al código** para explicar qué hace cada una de las líneas del código
#
# 1) ¿Qué pasa si cambiamos el "color" a "yellow" y "grey" ?
#
# 2) ¿Qué pasa si cambiamos el "shape" a "classic" ?
#
# 3) ¿Qué pasa si cambiamos el "pensize" a "10" ?
#
# 4) ¿Qué pasa si cambiamos la "speed" a "2" ?
#
# 5) ¿Qué pasa si cambiamos el circle(-50) a circle(-10) ?
#
# 6) ¿Qué pasa si eliminamos la línea que dice "clearscreen" ?
#
# 7) ¿Qué pasa si eliminamos la línea que dice "from ColabTurtlePlus.Turtle import * " ?
#
# 8) ¿Podrías dibujar una tortuga con borde negro y relleno verde?

# %%
from ColabTurtlePlus.Turtle import *

#Limpia la pantalla
clearscreen()

#Ajusta el cuadro
setup(400,400)

#Colores a utilizar
color("black", "green")

#Forma del lapiz
shape("turtle")

#Grosor
pensize(5)

#Velocidad de lapiz
speed(2)

#Dibuja circulo
circle(-100)
# Out:
#       <svg width="400" height="400">
#         <rect width="100%" height="100%" style="fill:white;stroke:;stroke-width:1"/>
#
#
#         <path d="M 200.0 200.0 A -100 -100 0 0 1 225.882 203.407" stroke-linecap="round"
#             fill="transparent" fill-opacity="0" style="stroke:black;stroke-width:5"/><path d="M 225.882 203.407 A -100 -100 0 0 1 250.0 213.397" stroke-linecap="round"
#             fill="transparent" fill-opacity="0" style="stroke:black;stroke-width:5"/><path d="M 250.0 213.397 A -100 -100 0 0 1 270.711 229.289" stroke-linecap="round"
#             fill="transparent" fill-opacity="0" style="stroke:black;stroke-width:5"/><path d="M 270.711 229.289 A -100 -100 0 0 1 286.603 250.0" stroke-linecap="round"
#             fill="transparent" fill-opacity="0" style="stroke:black;stroke-width:5"/><path d="M 286.603 250.0 A -100 -100 0 0 1 296.593 274.118" stroke-linecap="round"
# ...
